# %% [markdown]
# # Eksperimen Titanic - Nama Siswa

# %%
import pandas as pd
import matplotlib.pyplot as plt
train = pd.read_csv('../namadataset_raw/train.csv')
test = pd.read_csv('../namadataset_raw/test.csv')
print(train.shape, test.shape)
train.head()
# Out:
# (891, 12) (418, 11)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
train.info()
train.isna().sum().sort_values(ascending=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# Cabin          687
# Age            177
# Embarked         2
# PassengerId      0
# Name             0
# Pclass           0
# Survived         0
# Sex              0
# Parch            0
# SibSp            0
# ...

# %%
train.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
train.groupby('Pclass')['Survived'].mean().plot(kind='bar')
plt.tight_layout()

# %%
from automate_nama_siswa import preprocess
preprocess('../namadataset_raw/train.csv', '../namadataset_raw/test.csv', 'namadataset_preprocessing')
# Out:
# {'n_train_rows': 891,
#  'n_test_rows': 418,
#  'n_features_after_preprocessing': 59,
#  'target_column': 'Survived',
#  'id_column': 'PassengerId',
#  'raw_feature_columns': ['Pclass',
#   'Sex',
#   'Age',
#   'SibSp',
#   'Parch',
#   'Fare',
#   'Embarked',
#   'Title',
#   'FamilySize',
#   'IsAlone',
#   'TicketPrefix',
#   'CabinDeck',
#   'Age*Class',
#   'FarePerPerson'],
#  'transformed_feature_columns': ['num__Pclass',
#   'num__Age',
#   'num__SibSp',
#   'num__Parch',
#   'num__Fare',
#   'num__FamilySize',
#   'num__IsAlone',
#   'num__Age*Class',
#   'num__FarePerPerson',
#   'cat__Sex_female',
#   'cat__Sex_male',
#   'cat__Embarked_C',
#   'cat__Embarked_Q',
#   'cat__Embarked_S',
#   'cat__Title_Master',
#   'cat__Title_Miss',
#   'cat__Title_Mr',
#   'cat__Title_Mrs',
#   'cat__Title_Officer',
#   'cat__Title_Rare',
#   'cat__Title_Royalty',
#   'cat__TicketPrefix_A',
#   'cat__TicketPrefix_AS',
#   'cat__TicketPrefix_C',
#   'cat__TicketPrefix_CA',
# ...
